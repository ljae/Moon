# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Demographics_of_South_Korea"

# %%
table = pd.read_html(url)

# %%
# Out:
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...

# %%
table[8]
# Out:
#    Unnamed: 0  Average population  Live births  Deaths  Natural change  \
# 0        1925            12997611       558897  359042          199855
# 1        1926            13052741       511667  337948          173719
# 2        1927            13037169       534524  353818          180706
# 3        1928            13105131       566142  357701          208441
# 4        1929            13124279       566969  414366          152603
# ..        ...                 ...          ...     ...             ...
# 91       2016            51245707       406243  280827          125416
# 92       2017            51466201       357771  285534           72237
# 93   2018[25]            51635256       326822  298820           28002
# 94   2019[26]            51709098       302676  295132            7544
# 95   2020[27]            51829023       272410  305127          -32717
#
#     Crude birth rate (per 1000)  Crude death rate (per 1000)  \
# ...
